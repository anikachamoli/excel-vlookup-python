# %%
import pandas as pd
import openpyxl
from pathlib import Path
DATA_DIR = Path.cwd() / 'data'

# %%
excel_file = pd.ExcelFile(excel_file_path)
sheet_names = excel_file.sheet_names
sheet_names
# Out:
# ['Orders', 'Returns', 'Shipping']

# %% [markdown]
# ## Read Excel Data

# %%
dataframes = {}
for sheet_name in sheet_names:
    dataframes[sheet_name] = pd.read_excel(excel_file,sheet_name = sheet_name)

dataframes['Orders'].head(3)
# Out:
#          Order ID Order Date       Ship Mode
# 0  CA-2017-157252 2020-01-20    Second Class
# 1  CA-2017-154214 2020-03-20    Second Class
# 2  CA-2017-147277 2020-10-20  Standard Class

# %%
orders.head()
# Out:
#          Order ID Order Date       Ship Mode
# 0  CA-2017-157252 2020-01-20    Second Class
# 1  CA-2017-154214 2020-03-20    Second Class
# 2  CA-2017-147277 2020-10-20  Standard Class
# 3  CA-2017-147277 2020-10-20  Standard Class
# 4  CA-2017-154907 2020-03-31  Standard Class

# %%
returns.head()
# Out:
#   Returned              ID              Reason
# 0      Yes  CA-2017-153822  Damaged/ Defective
# 1      Yes  CA-2017-129707       Not Satisfied
# 2      Yes  CA-2014-152345       Not Satisfied
# 3      Yes  CA-2015-156440        Late Arrival
# 4      Yes  US-2017-155999     Wrong Item Sent

# %%
shipping.head()
# Out:
#         Ship Mode  Ship Mode No.
# 0     First Class              1
# 1        Same Day              2
# 2    Second Class              3
# 3  Standard Class              4

# %% [markdown]
# ## VlookUp

# %%
df1 = orders.merge(returns,
                  left_on= 'Order ID',
                  right_on = 'ID',
                  how= 'left')
df1.head()
# Out:
#          Order ID Order Date       Ship Mode Returned              ID  \
# 0  CA-2017-157252 2020-01-20    Second Class      NaN             NaN
# 1  CA-2017-154214 2020-03-20    Second Class      Yes  CA-2017-154214
# 2  CA-2017-147277 2020-10-20  Standard Class      NaN             NaN
# 3  CA-2017-147277 2020-10-20  Standard Class      NaN             NaN
# 4  CA-2017-154907 2020-03-31  Standard Class      NaN             NaN
#
#                Reason
# 0                 NaN
# 1  Damaged/ Defective
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
df2 = df1.merge(shipping,
                left_on= 'Ship Mode',
                right_on= 'Ship Mode',
                how= 'left')
df2.head()
# Out:
#          Order ID Order Date       Ship Mode Returned              ID  \
# 0  CA-2017-157252 2020-01-20    Second Class      NaN             NaN
# 1  CA-2017-154214 2020-03-20    Second Class      Yes  CA-2017-154214
# 2  CA-2017-147277 2020-10-20  Standard Class      NaN             NaN
# 3  CA-2017-147277 2020-10-20  Standard Class      NaN             NaN
# 4  CA-2017-154907 2020-03-31  Standard Class      NaN             NaN
#
#                Reason  Ship Mode No.
# 0                 NaN              3
# 1  Damaged/ Defective              3
# 2                 NaN              4
# 3                 NaN              4
# 4                 NaN              4

# %%
excel_output_path = DATA_DIR / 'output.xlsx'
df2.to_excel(excel_output_path,
            sheet_name= 'Output',
            index=False)
